# %% [markdown]
# # Purpose

# %% [markdown]
# # Import packages

# %%
using Pkg
Pkg.status()
# Out:
# Status `D:\Utilizador HDD\Google Drive\02-Projects\Notebooks-Research\Statistics\Project.toml`
#   [a93c6f00] DataFrames v1.6.1
# ⌃ [31c24e10] Distributions v0.25.108
#   [38e38edf] GLM v1.9.0
#   [09f84164] HypothesisTests v0.11.0
# ⌃ [91a5bcdd] Plots v1.40.4
#   [295af30f] Revise v3.5.15
#   [3eaba693] StatsModels v0.7.3
#   [f3b207a7] StatsPlots v0.15.7
# Info Packages marked with ⌃ have new versions available and may be upgradable.

# %%
using Random
using Revise
using Distributions
using Plots.PlotMeasures
using StatsPlots
using DataFrames
using Printf
using GLM
using StatsModels

# %%
includet("helpers/structs.jl")
includet("helpers/functions.jl")

# %% [markdown]
# # Generate some sampele data for the regressions

# %%
rng = Random.seed!(1)
# Out:
# TaskLocalRNG()

# %%
n_total = 20

data_growth = DataFrame(; age=[13:(n_total/2+12); 13:(n_total/2+12)],
    sex=repeat(["male", "female"], inner=Int(n_total / 2)),
    weight=[range(100, 155; length=Int(n_total / 2)); range(100, 125; length=Int(n_total / 2))] .+ 2 * randn(rng, n_total))
data_growth
# Out:
# 20×3 DataFrame
#  Row │ age      sex     weight
#      │ Float64  String  Float64
# ─────┼──────────────────────────
#    1 │    13.0  male    100.124
#    2 │    14.0  male    106.668
#    3 │    15.0  male    111.031
#    4 │    16.0  male    118.427
#    5 │    17.0  male    126.616
#    6 │    18.0  male    127.402
#    7 │    19.0  male    137.019
#    8 │    20.0  male    144.509
#   ⋮  │    ⋮       ⋮        ⋮
#   14 │    16.0  female  108.348
#   15 │    17.0  female  113.233
#   16 │    18.0  female  110.84
#   17 │    19.0  female  118.611
#   18 │    20.0  female  122.537
#   19 │    21.0  female  121.054
#   20 │    22.0  female  125.935
#                   5 rows omitted

# %%
data_male = filter(:sex => s -> s == "male", data_growth)
data_female = filter(:sex => s -> s == "female", data_growth);

# %%
scatter(
    data_male[:, :age],
    data_male[:, :weight],
    markercolor="deepskyblue",
    label="Male"
)

scatter!(
    data_female[:, :age],
    data_female[:, :weight],
    markercolor="orange",
    label="Female"
)

# %% [markdown]
# # Simple linear regression with GLM package

# %%
ols = lm(@formula(weight ~ age + sex), data_growth)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# weight ~ 1 + age + sex
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────
# (Intercept)  37.6843     6.76277    5.57    <1e-04   23.4161    51.9525
# age           4.29547    0.376436  11.41    <1e-08    3.50126    5.08968
# sex: male    13.7768     2.16246    6.37    <1e-05    9.21444   18.3392
# ────────────────────────────────────────────────────────────────────────

# %%
data_growth[!, "predictions"] = predict(ols)
# Out:
# 20-element Vector{Float64}:
#  107.30225826809284
#  111.59773095787575
#  115.89320364765867
#  120.18867633744158
#  124.48414902722449
#  128.77962171700744
#  133.07509440679036
#  137.37056709657327
#  141.66603978635618
#  145.9615124761391
#   93.52542576580186
#   97.82089845558477
#  102.11637114536768
#  106.41184383515059
#  110.7073165249335
#  115.00278921471644
#  119.29826190449936
#  123.59373459428227
#  127.88920728406518
#  132.1846799738481

# %%
scatter(
    data_male[:, :age],
    data_male[:, :weight],
    markercolor="deepskyblue",
    label="Male"
)

scatter!(
    data_female[:, :age],
    data_female[:, :weight],
    markercolor="orange",
    label="Female"
)

predictions = predict(ols)

plot!(
    filter(:sex => n -> n == "male", data_growth)[:, :age],
    filter(:sex => n -> n == "male", data_growth)[:, :predictions],
    linecolor="darkblue",
    linewidth=2,
    label="OLS Prediction (GLM package) - Male"
)

plot!(
    filter(:sex => n -> n == "female", data_growth)[:, :age],
    filter(:sex => n -> n == "female", data_growth)[:, :predictions],
    linecolor="darkorange",
    linewidth=2,
    label="OLS Prediction (GLM package) - Male"
)

# %% [markdown]
# - Note that with a simple linear model the slopes are not allowed to be different and then the data does not seem to fit as well as it should
# - We should try, for example, a mixed model

# %% [markdown]
# # Hand made

# %%
@doc LinearModelOLS
# Out:
#   LinearModelOLS(formula::FormulaTerm, data::DataFrames.DataFrame)
#
#   Compute a Multiple Linear Regression
#
#   Method
#   ≡≡≡≡≡≡
#
#     •  The parameters are estimated via Ordinary Least Squares (OLS)
#
#   OLS is an analytical solution that is equivalent to the MLE for a certain
#   type of linear regression:
#
#     •  The model is correctly specified:
#        • We have not omitted important variables in the model
#        (underfitting the data)
#        • We do not have redundant variables in the model
#        (overfitting the data)
#        • The necessary transformations of the variables are
#        applied (e.g. to linearize the relation to the response
#        variable in the case of linear regressions)
#        • We do not have outliers in the residuals of the model
#
#     •  The residuals are independent and identically distributed
#
#     •  The explanatory variables are not correlated with anything but the
#        response variable
#
#   The OLS equations are derived from minimizing the Sum of Squared Errors
#   (SSE) (see proof here (https://openforecast.org/sba/OLS.html))
#
#   For the linear regression, the OLS estimator produces the Best Linear
#   Unbiased Estimates (BLUE), as shown by the Gauss Markov theorem. Explanation
#   here
#   (https://www.statlect.com/fundamentals-of-statistics/Gauss-Markov-theorem).

# %%
ols_hand = LinearModelOLS(@formula(weight ~ age + sex), data_growth)
# Out:
# ┌ Info: Parameter estimation:
# │   b0 = -5.809034845692203
# │   b1 = 7.2978632673530495
# └ @ Main d:\Utilizador HDD\Google Drive\02-Projects\Notebooks-Research\Statistics\Regressions\helpers\structs.jl:142
# ┌ Info: predictor:
# │   predictor = ["age", "sex"]
# └ @ Main d:\Utilizador HDD\Google Drive\02-Projects\Notebooks-Research\Statistics\Regressions\helpers\structs.jl:158
# MethodError: Cannot `convert` an object of type Vector{String} to an object of type String
#
#
#
# Closest candidates are:
#
#   convert(::Type{String}, !Matched::StringManipulation.Decoration)
#
#    @ StringManipulation C:\Users\linki_000\.julia\packages\StringManipulation\5Zfrz\src\decorations.jl:315
#
#   convert(::Type{String}, !Matched::Base.JuliaSyntax.Kind)
#
#    @ Base C:\workdir\base\JuliaSyntax\src\kinds.jl:975
#
#   convert(::Type{String}, !Matched::String)
#
#    @ Base essentials.jl:321
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#  [1] setindex!(h::Dict{String, Real}, v0::Float64, key0::Vector{String})
#
#    @ Base .\dict.jl:367
#
#  [2] Dict{String, Real}(::Pair{String, Float64}, ::Vararg{Pair})
#
#    @ Base .\dict.jl:93
#
#  [3] LinearModelOLS(formula::FormulaTerm{Term, Tuple{Term, Term}}, data::DataFrame)
#
#    @ Main d:\Utilizador HDD\Google Drive\02-Projects\Notebooks-Research\Statistics\Regressions\helpers\structs.jl:161
#
#  [4] top-level scope
#
#    @ d:\Utilizador HDD\Google Drive\02-Projects\Notebooks-Research\Statistics\Regressions\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X21sZmlsZQ==.jl:1

# %%
ols
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}, Vector{Int64}}}}, Matrix{Float64}}
#
# weight ~ 1 + age + sex
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────
#                 Coef.  Std. Error      t  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────
# (Intercept)  37.6843     6.76277    5.57    <1e-04   23.4161    51.9525
# age           4.29547    0.376436  11.41    <1e-08    3.50126    5.08968
# sex: male    13.7768     2.16246    6.37    <1e-05    9.21444   18.3392
# ────────────────────────────────────────────────────────────────────────

# %% [markdown]
# - The coefficients match the GLM package coefficients

# %% [markdown]
# ## Plot the predictions

# %%
scatter(
    data_male[:, :age],
    data_male[:, :weight],
    markercolor="deepskyblue",
    label="Male"
)

predictions = predict(ols)
predictions_hand = hand_predict(ols_hand)

plot!(
    data_male[:, :age],
    predictions,
    linecolor="orange",
    linewidth=2,
    label="OLS Prediction (GLM package)"
)

plot!(
    data_male[:, :age],
    predictions_hand,
    linecolor="red",
    linewidth=2,
    linestyle=:dash,
    label="OLS Prediction (by hand)"
)

# %% [markdown]
# - The prediction function that takes the coefficients and multiplies the data (adding the intercept) also matches the GLM package predictions

# %% [markdown]
# ## Check other parameters

# %%
println(ols_hand.SST)
println(ols_hand.SSR)
println(ols_hand.SSE)
println(ols_hand.R²)
# Out:
# 2722.4940493555114
# 2679.0780678099954
# 43.41598154551571
# 0.9840528644843893

# %%
println(ols_hand.coefs)
# Out:
# Dict{String, Real}("Intercept" => 26.906951055535274, "age" => 5.698567675233183)

# %% [markdown]
# # Explore the breakdown of the OLS assumptions
