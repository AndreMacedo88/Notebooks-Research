# %% [markdown]
# # Purpose
#
# - In this notebook we explore some algorithms that can be used to estimate maximum likelihood parameters
# - The use pros and cons of each will be stated
# - List of current methods:
#   - Newton-Raphson
#   - Expectation Maximization

# %%
library(stats)
library(tidyverse)
library(ggplot2)
library(patchwork)
